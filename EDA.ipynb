# %%
import pandas as pd
import pandas_profiling

# %%
local_path = "data/raw/census.csv"
df = pd.read_csv(local_path, skipinitialspace = True)
# df = pd.read_csv(local_path)

# %%
profile = pandas_profiling.ProfileReport(df)
# profile.to_widgets()
profile.to_notebook_iframe()
# Out:
# Summarize dataset:  92%|█████████▏| 59/64 [00:35<00:05,  1.13s/it, Missing diagram matrix]

# %%
df.describe()
# Out:
#                 age         fnlgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.head()
# Out:
#    age         workclass   fnlgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# Drop rows containing ? value

# %%
df.replace({'?': None}, inplace=True)
df.dropna(inplace=True)

# %% [markdown]
# Drop columns:
#
# - "fnlgt" is just a weight that should not impact prediction
# - "education-num": is very highly correlated education type
# - "capital-gain": almost everyone got zero
# - "capital-loss": almost everyone got zero

# %%
df.drop("fnlgt", axis="columns", inplace=True)
df.drop("education-num", axis="columns", inplace=True)
df.drop("capital-gain", axis="columns", inplace=True)
df.drop("capital-loss", axis="columns", inplace=True)

# %%
profile = pandas_profiling.ProfileReport(df)
profile.to_widgets()
# Out:
# Summarize dataset: 100%|██████████| 34/34 [00:24<00:00,  1.41it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:09<00:00,  9.47s/it]
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Input In [14], in <module>
#       1 profile = pandas_profiling.ProfileReport(df)
# ----> 2 profile.to_widgets()
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/profile_report.py:414, in ProfileReport.to_widgets(self)
#     410     pass
#     412 from IPython.core.display import display
# --> 414 display(self.widgets)
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/profile_report.py:197, in ProfileReport.widgets(self)
#     194 @property
#     195 def widgets(self) -> Renderable:
#     196     if self._widgets is None:
# --> 197         self._widgets = self._render_widgets()
#     198     return self._widgets
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/profile_report.py:323, in ProfileReport._render_widgets(self)
#     315 report = self.report
#     317 with tqdm(
#     318     total=1,
#     319     desc="Render widgets",
#     320     disable=not self.config.progress_bar,
#     321     leave=False,
#     322 ) as pbar:
# --> 323     widgets = WidgetReport(copy.deepcopy(report)).render()
#     324     pbar.update()
#     325 return widgets
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/root.py:9, in WidgetRoot.render(self, **kwargs)
#       7 def render(self, **kwargs) -> widgets.VBox:
#       8     return widgets.VBox(
# ----> 9         [self.content["body"].render(), self.content["footer"].render()]
#      10     )
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:106, in WidgetContainer.render(self)
#     104     widget = get_named_list(self.content["items"])
#     105 elif self.sequence_type in ["tabs", "sections", "select"]:
# --> 106     widget = get_tabs(self.content["items"])
#     107 elif self.sequence_type == "accordion":
#     108     widget = get_accordion(self.content["items"])
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:20, in get_tabs(items)
#      18 titles = []
#      19 for item in items:
# ---> 20     children.append(item.render())
#      21     titles.append(get_name(item))
#      23 tab = widgets.Tab()
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:108, in WidgetContainer.render(self)
#     106     widget = get_tabs(self.content["items"])
#     107 elif self.sequence_type == "accordion":
# --> 108     widget = get_accordion(self.content["items"])
#     109 elif self.sequence_type == "grid":
#     110     widget = get_row(self.content["items"])
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:89, in get_accordion(items)
#      87 titles = []
#      88 for item in items:
# ---> 89     children.append(item.render())
#      90     titles.append(get_name(item))
#      92 accordion = widgets.Accordion(children=children)
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/variable.py:10, in WidgetVariable.render(self)
#       8 items = [self.content["top"].render()]
#       9 if self.content["bottom"] is not None:
# ---> 10     items.append(self.content["bottom"].render())
#      12 return widgets.VBox(items)
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/collapse.py:14, in WidgetCollapse.render(self)
#      11     collapse = "variable"
#      13 toggle = self.content["button"].render()
# ---> 14 item = self.content["item"].render()
#      16 if collapse == "correlation":
#      18     def toggle_func(widg: dict) -> None:
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:106, in WidgetContainer.render(self)
#     104     widget = get_named_list(self.content["items"])
#     105 elif self.sequence_type in ["tabs", "sections", "select"]:
# --> 106     widget = get_tabs(self.content["items"])
#     107 elif self.sequence_type == "accordion":
#     108     widget = get_accordion(self.content["items"])
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:20, in get_tabs(items)
#      18 titles = []
#      19 for item in items:
# ---> 20     children.append(item.render())
#      21     titles.append(get_name(item))
#      23 tab = widgets.Tab()
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:110, in WidgetContainer.render(self)
#     108     widget = get_accordion(self.content["items"])
#     109 elif self.sequence_type == "grid":
# --> 110     widget = get_row(self.content["items"])
#     111 elif self.sequence_type == "batch_grid":
#     112     widget = get_batch_grid(
#     113         self.content["items"],
#     114         self.content["batch_size"],
#     115         self.content.get("titles", True),
#     116         self.content.get("subtitles", False),
#     117     )
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:57, in get_row(items)
#      54 else:
#      55     raise ValueError("Layout undefined for this number of columns")
# ---> 57 return widgets.GridBox([item.render() for item in items], layout=layout)
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:57, in <listcomp>(.0)
#      54 else:
#      55     raise ValueError("Layout undefined for this number of columns")
# ---> 57 return widgets.GridBox([item.render() for item in items], layout=layout)
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:106, in WidgetContainer.render(self)
#     104     widget = get_named_list(self.content["items"])
#     105 elif self.sequence_type in ["tabs", "sections", "select"]:
# --> 106     widget = get_tabs(self.content["items"])
#     107 elif self.sequence_type == "accordion":
#     108     widget = get_accordion(self.content["items"])
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:20, in get_tabs(items)
#      18 titles = []
#      19 for item in items:
# ---> 20     children.append(item.render())
#      21     titles.append(get_name(item))
#      23 tab = widgets.Tab()
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:104, in WidgetContainer.render(self)
#     102     widget = get_list(self.content["items"])
#     103 elif self.sequence_type == "named_list":
# --> 104     widget = get_named_list(self.content["items"])
#     105 elif self.sequence_type in ["tabs", "sections", "select"]:
#     106     widget = get_tabs(self.content["items"])
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:36, in get_named_list(items)
#      34 def get_named_list(items: List[Renderable]) -> widgets.VBox:
#      35     return widgets.VBox(
# ---> 36         [
#      37             widgets.VBox(
#      38                 [widgets.HTML(f"<strong>{get_name(item)}</strong>"), item.render()]
#      39             )
#      40             for item in items
#      41         ]
#      42     )
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:38, in <listcomp>(.0)
#      34 def get_named_list(items: List[Renderable]) -> widgets.VBox:
#      35     return widgets.VBox(
#      36         [
#      37             widgets.VBox(
# ---> 38                 [widgets.HTML(f"<strong>{get_name(item)}</strong>"), item.render()]
#      39             )
#      40             for item in items
#      41         ]
#      42     )
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/frequency_table.py:56, in WidgetFrequencyTable.render(self)
#      45     else:
#      46         items.append(
#      47             (
#      48                 widgets.Label(str(row["label"])),
#    (...)
#      53             )
#      54         )
# ---> 56 return get_table(items)
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/frequency_table.py:11, in get_table(items)
#       8 def get_table(
#       9     items: List[Tuple[widgets.Label, widgets.FloatProgress, widgets.Label]]
#      10 ) -> VBox:
# ---> 11     table = GridspecLayout(len(items), 3)
#      12     for row_id, (label, progress, count) in enumerate(items):
#      13         table[row_id, 0] = label
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/ipywidgets/widgets/widget_templates.py:282, in GridspecLayout.__init__(self, n_rows, n_columns, **kwargs)
#     280 def __init__(self, n_rows=None, n_columns=None, **kwargs):
#     281     super(GridspecLayout, self).__init__(**kwargs)
# --> 282     self.n_rows = n_rows
#     283     self.n_columns = n_columns
#     284     self._grid_template_areas = [['.'] * self.n_columns for i in range(self.n_rows)]
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/traitlets/traitlets.py:606, in TraitType.__set__(self, obj, value)
#     604     raise TraitError('The "%s" trait is read-only.' % self.name)
#     605 else:
# --> 606     self.set(obj, value)
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/traitlets/traitlets.py:580, in TraitType.set(self, obj, value)
#     579 def set(self, obj, value):
# --> 580     new_value = self._validate(obj, value)
#     581     try:
#     582         old_value = obj._trait_values[self.name]
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/traitlets/traitlets.py:614, in TraitType._validate(self, obj, value)
#     612     value = self.validate(obj, value)
#     613 if obj._cross_validation_lock is False:
# --> 614     value = self._cross_validate(obj, value)
#     615 return value
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/traitlets/traitlets.py:620, in TraitType._cross_validate(self, obj, value)
#     618 if self.name in obj._trait_validators:
#     619     proposal = Bunch({'trait': self, 'value': value, 'owner': obj})
# --> 620     value = obj._trait_validators[self.name](obj, proposal)
#     621 elif hasattr(obj, '_%s_validate' % self.name):
#     622     meth_name = '_%s_validate' % self.name
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/traitlets/traitlets.py:977, in EventHandler.__call__(self, *args, **kwargs)
#     975 """Pass `*args` and `**kwargs` to the handler's function if it exists."""
#     976 if hasattr(self, 'func'):
# --> 977     return self.func(*args, **kwargs)
#     978 else:
#     979     return self._init_call(*args, **kwargs)
#
# File ~/miniconda3/envs/proj3_env/lib/python3.8/site-packages/ipywidgets/widgets/widget_templates.py:295, in GridspecLayout._validate_integer(self, proposal)
#     293 if proposal['value'] > 0:
#     294     return proposal['value']
# --> 295 raise TraitError('n_rows and n_columns must be positive integer')
#
# TraitError: n_rows and n_columns must be positive integer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 0 to 32560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   education       30162 non-null  object
#  3   marital-status  30162 non-null  object
#  4   occupation      30162 non-null  object
#  5   relationship    30162 non-null  object
#  6   race            30162 non-null  object
#  7   sex             30162 non-null  object
#  8   hours-per-week  30162 non-null  int64
#  9   native-country  30162 non-null  object
#  10  salary          30162 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 2.8+ MB
